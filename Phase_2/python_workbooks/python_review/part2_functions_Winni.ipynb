# %% [markdown]
# ## Imported function usage
#
# Using the imported `math` function, calculate the following of pi and print:
#
# * the "floor" of pi (rounding down to 3.00)
# * the "ceiling" of pi (rounding up to 4.00)
# * pi to the second power (3.14 ^ 2)
#
# Be sure to consult the following documentation:
# https://docs.python.org/3/library/math.html

# %%
import math

pi = 3.14

floor = (f"{math.floor(math.pi):.2f}")
ceiling = (f"{math.ceil(math.pi):.2f}") 
power = (f"{pow(pi,pi):.2f}") 

print("The floor of pi is", floor)
print("The ceiling of pi is", ceiling)
print("Pi squared is", power)
# Out:
# The floor of pi is 3.00
# The ceiling of pi is 4.00
# Pi squared is 36.34

# %% [markdown]
# ## Adder
#
# Create a function called `add(a, b)` that takes two values and computes their sum.
#
# Call this function using the two variables `num1` and `num2`.

# %%
num1 = 10
num2 = 5

# write solution here
def add(a, b):
    return a + b

# %%
print(add(num1, num2) == 15)
# Out:
# True

# %% [markdown]
# ## Subtracter
#
# Create a function called `subtract(a, b)` that takes two values and computes the ir ifference.
#
# Call this function using the two variables `num1` and `num2`.

# %%
num1 = 10
num2 = 5

# write solution here
def subtract(a, b):
    return a - b

# %%
print(subtract(num1, num2) == 5)
# Out:
# True

# %% [markdown]
# ## Multiplier
#
# Create a function called `multiply(a, b)` that takes two values and computes their product.
#
# Call this function using the two variables `num1` and `num2`.

# %%
num1 = 10
num2 = 5

# write solution here
def multiply(a, b):
    return a * b

# %%
print(multiply(num1, num2) == 50)
# Out:
# True

# %% [markdown]
# ## Divider
#
# Create a function called `divide(a, b)` that takes two values and computes their quotient.
#
# Call this function using the two variables `num1` and `num2`.

# %%
num1 = 10
num2 = 5

# write solution here
def divide(a, b):
    return a / b

# %%
print(divide(num1, num2) == 2)
# Out:
# True

# %% [markdown]
# ## List Mutator
#
# Create a function named `capitalize_all(lst)` that takes in the list created for us below, and returns a copy of this with all the letters capitalized.
#
# Be sure to include the docstring!

# %%
letters = ["a", "b", "c", "d", "e", "f", "g", "h"]

# write function here
def capitalize_all(letters):
    return letters.upper()

# return [item.upper() for item in lst]

# %%
print(capitalize_all(letters == ["A", "B", "C", "D", "E", "F", "G", "H"]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(capitalize_all(letters == ["A", "B", "C", "D", "E", "F", "G", "H"]))
#
# Cell In[14], line 5, in capitalize_all(letters)
#       4 def capitalize_all(letters):
# ----> 5     return letters.upper()
#
# AttributeError: 'bool' object has no attribute 'upper'

# %% [markdown]
# ## Multiplier DocStrings
#
# Write docstrings to your `multiply` functions.

# %%
num1 = 10
num2 = 5

# complete function
def multiply(a, b):
    """
    """
    return a * b

multiply(num1, num2)

# %% [markdown]
# ## Converter
#
# Write a function called `converter` that takes in a list of numbers represented as stirngs, and converts them all to floats.

# %%
# complete function
def converter(arr):
    pass

# %%
print(converter(['1', '2', '3'] == [1, 2, 3]))
